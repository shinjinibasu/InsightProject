# %%
import numpy as np
import pandas as pd
from surprise import dump
from surprise.prediction_algorithms.matrix_factorization import SVD
from surprise_functions import get_n_rec_user

# %%
_,model = dump.load('surprise_svd_dump_file')

test = pd.read_csv('testset.csv')
user_df = pd.read_csv('goodreads2/user_w_uid_bavg_titles.csv')
div_m = pd.read_csv('goodreads2/div_array.csv')

# %%
from surprise_functions import titles_from_ids

# %%
st = 'The New Jim Crow: Mass Incarceration in the Age of Colorblindness'

# %%
uids = list(range(-3,1514))

# %%
type(uids)
# Out:
# list

# %%
len(uids)
# Out:
# 1517

# %%
import random

ul = random.sample(uids,100)

# %%
ul =[1500 if x==2 else x for x in ul]

# %%
recs = []

for uid in ul:
    recs.append(get_n_rec_user(user_df,uid,model,div_m,test))

# %%
rec_w_uid = list(zip(ul,recs))

# %%
len(recs)
# Out:
# 100

# %%
rec = recs.copy()

# %%
for i in range(100):
    rec[i] = pd.Series(rec[i]).fillna('').tolist()
    rec[i] = [x.replace(st,'The Hate U Give') for x in rec[i]]

# %%
rec_w_uid = list(zip(ul,rec))

# %%
rec_w_uid
# Out:
# [(534,
#   ['The Hate U Give',
#    'Crooked Kingdom',
#    'Just Mercy: A Story of Justice and Redemption',
#    'Death Note #7',
#    'Flight: A Novel']),
#  (324,
#   ['Just Mercy: A Story of Justice and Redemption',
#    'The Hate U Give',
#    'Angels in America: A Gay Fantasia on National Themes: Millennium Approaches (Part One)',
#    'Matterhorn: A Novel of the Vietnam War',
#    'The Song of Achilles']),
#  (326, ["I'll Give You the Sun", '', "Kushiel's Avatar", '', '']),
#  (255,
#   ['We Should All Be Feminists',
#    'The Fifth Season',
#    'Musashi',
#    'Paradise Kiss 1',
#    'Labyrinths']),
#  (1166,
#   ['Matterhorn: A Novel of the Vietnam War',
#    'The Hate U Give',
#    'Saga, Volume Three',
#    'The Fifth Season',
#    'West with the Night']),
#  (340,
#   ['Just Mercy: A Story of Justice and Redemption',
#    'Matterhorn: A Novel of the Vietnam War',
#    'The Girl Who Circumnavigated Fairyland in a Ship of Her Own Making',
# ...

# %%
rec = [[w.replace("デスノート #7 (Desu Nōto) Zero (零)",'Death Note #7') for w  in row] for row in rec]

# %%
rec = [[w.replace("デスノート",'Death Note') for w  in row] for row in rec]

# %%
rec = [[w.replace('(Desu Nōto)','') for w in row] for row in rec]

# %%
rec = [[w.replace('宮本武蔵 Miyamoto Musashi','Musashi') for w in row] for row in rec]

# %%
rec
# Out:
# [['The Hate U Give',
#   'Crooked Kingdom',
#   'Just Mercy: A Story of Justice and Redemption',
#   'Death Note #7',
#   'Flight: A Novel'],
#  ['Just Mercy: A Story of Justice and Redemption',
#   'The Hate U Give',
#   'Angels in America: A Gay Fantasia on National Themes: Millennium Approaches (Part One)',
#   'Matterhorn: A Novel of the Vietnam War',
#   'The Song of Achilles'],
#  ["I'll Give You the Sun", '', "Kushiel's Avatar", '', ''],
#  ['We Should All Be Feminists',
#   'The Fifth Season',
#   'Musashi',
#   'Paradise Kiss 1',
#   'Labyrinths'],
#  ['Matterhorn: A Novel of the Vietnam War',
#   'The Hate U Give',
#   'Saga, Volume Three',
#   'The Fifth Season',
#   'West with the Night'],
#  ['Just Mercy: A Story of Justice and Redemption',
#   'Matterhorn: A Novel of the Vietnam War',
#   'The Girl Who Circumnavigated Fairyland in a Ship of Her Own Making',
#   'Citizen: An American Lyric',
#   'Aristotle and Dante Discover the Secrets of the Universe'],
# ...

# %%
pd.DataFrame(rec_w_uid,columns=['user_id','recs']).to_csv('user_recs',index=None)

# %%
uid2 = set(uids) - set(ul)

# %%
ul2 = random.sample(uid2,100)

# %%
recs = []

for uid in ul2:
    recs.append(get_n_rec_user(user_df,uid,model,div_m,test))

# %%
recs_w_uid
# Out:
# [(1462,
#   ['The Fifth Season',
#    'Nimona',
#    "The Warmth of Other Suns: The Epic Story of America's Great Migration ",
#    'The Hate U Give',
#    'The Palace of Illusions']),
#  (822,
#   ['The Fifth Season',
#    'Half the Sky: Turning Oppression into Opportunity for Women Worldwide',
#    'Paradise Kiss 1',
#    'The Hate U Give',
#    'Tikki Tikki Tembo']),
#  (355,
#   ["I'll Give You the Sun",
#    'Crooked Kingdom',
#    'Malgudi Days',
#    'News of the World',
#    '']),
#  (202,
#   ['Angels in America:  A Gay Fantasia on National Themes',
#    'Ship of Magic',
#    'The Twentieth Wife',
#    'Matterhorn: A Novel of the Vietnam War',
#    'Kindred']),
#  (1267,
#   ['Essential Rumi',
#    'Half the Sky: Turning Oppression into Opportunity for Women Worldwide',
#    'The Hate U Give',
#    '',
#    'Sinuhe egyptiläinen ']),
#  (796,
#   ['Just Mercy: A Story of Justice and Redemption',
#    'The Hate U Give',
#    'Nimona',
# ...

# %%
recs = [pd.Series(row).fillna('').tolist() for row in recs]
recs = [[w.replace(st,'The Hate U Give') for w  in row] for row in recs]

# %%
recs = ['<br>'.join(w) for w in recs]

# %%
recs = [w.replace('[','') for w in recs]
recs = [w.replace("]",'') for w in recs]

# %%
recs_w_uid = list(zip(ul2,recs))

# %%
recs_w_uid = rec_w_uid + recs_w_uid

# %%
len(recs_w_uid)
# Out:
# 200

# %%
names = ["Brianne","John","Bennett","Brandon","Yaarit","Danila","Daliang","Steven","Randolph","Alex","Gary","Julia","Ilia","Chang","Daniel","Kai","Jason","Victoria","Antoine","Wenke","Avi","Jesse","Anna","Nina","Paul","Avery"]

# %%
names = names + ["Hugo","Charlie","Dewey","Jamel","Magdalena","Molly","Sherry","Curtis","Thad","Junior","Seymour","Betty","Otto","Elsie","May","Marcelino","Roger","Graciela","Ashley","Antony","Tameka","Andreas","Fermin","Garland","Sol","Joshua","Gavin","Whitney","Shelby","Coy","Wm","Myra","Dalton","Williams","Danial","Sophia","Krista","Samuel","Polly","Veronica","Winfred","Erwin","Tonya","Markus","Marisa","Houston","Numbers","Kris","Darcy","Kenny","Dwight","Ronda","Clarice","Wendell","Gerardo","Millard","Jeffry","Mitch","Haywood","Dylan","Terrence","Jeanne","Leopoldo","Clifton","Cornelius","Linwood","Rolando","Alyson","Darren","Maximo","Vance","Rocky","Robert","Darrin","Cole","Augusta","Gilberto","Eloy","Dino","Malcolm","Bessie","Roseann","Norman","Allyson","Abe","Antwan","Stevie","Claudio","Blair","Keisha","Goldie","Lucy","Byron","Reyes","Zachery","Stefan","Aron","Cecile","Brent","Avery"]

# %%
len(names)
# Out:
# 126

# %%
import pandas as pd
names = pd.Series(names).drop_duplicates().to_list()

# %%
len(names)
# Out:
# 125

# %%
recs_df = pd.DataFrame(recs_w_uid,columns=['user_id','recs'])

# %%
recs_df = recs_df.loc[~recs_df.user_id.isin([326,1185,607])]

# %%
recs_w_uid
# Out:
# [(534,
#   ['The Hate U Give',
#    'Crooked Kingdom',
#    'Just Mercy: A Story of Justice and Redemption',
#    'Death Note #7',
#    'Flight: A Novel']),
#  (324,
#   ['Just Mercy: A Story of Justice and Redemption',
#    'The Hate U Give',
#    'Angels in America: A Gay Fantasia on National Themes: Millennium Approaches (Part One)',
#    'Matterhorn: A Novel of the Vietnam War',
#    'The Song of Achilles']),
#  (326, ["I'll Give You the Sun", '', "Kushiel's Avatar", '', '']),
#  (255,
#   ['We Should All Be Feminists',
#    'The Fifth Season',
#    'Musashi',
#    'Paradise Kiss 1',
#    'Labyrinths']),
#  (1166,
#   ['Matterhorn: A Novel of the Vietnam War',
#    'The Hate U Give',
#    'Saga, Volume Three',
#    'The Fifth Season',
#    'West with the Night']),
#  (340,
#   ['Just Mercy: A Story of Justice and Redemption',
#    'Matterhorn: A Novel of the Vietnam War',
#    'The Girl Who Circumnavigated Fairyland in a Ship of Her Own Making',
# ...

# %%
names = names + ["Adam","Emily","Allen","Donald","Amanda","Kim","Jen","Jolene","Ethan","Dennis","Taissa","Ricardo","Alyssa"]

# %%
names = pd.Series(names).drop_duplicates().to_list()

# %%
len(names)
# Out:
# 138

# %%
idx = []
for i in range(197):
    if '' in recs_df.iloc[i]['recs']:
        idx.append(i)

# %%
len(idx)
# Out:
# 38

# %%
idx = list(idx)

# %%
idx
# Out:
# [8,
#  12,
#  26,
#  33,
#  39,
#  40,
#  42,
#  53,
#  56,
#  61,
#  62,
#  68,
#  71,
#  75,
#  76,
#  79,
#  80,
#  88,
#  89,
#  95,
#  99,
#  101,
#  103,
#  104,
#  110,
#  116,
#  118,
#  121,
#  123,
#  128,
#  132,
#  133,
#  154,
#  161,
#  162,
#  172,
#  194,
#  195]

# %%
recs_df.reset_index(inplace=True)

# %%
recs_df.drop('index',axis=1)
# Out:
#      user_id                                               recs
# 0        534  [The Hate U Give, Crooked Kingdom, Just Mercy:...
# 1        324  [Just Mercy: A Story of Justice and Redemption...
# 2        255  [We Should All Be Feminists, The Fifth Season,...
# 3       1166  [Matterhorn: A Novel of the Vietnam War, The H...
# 4        340  [Just Mercy: A Story of Justice and Redemption...
# ..       ...                                                ...
# 154      503  [バクマン。 1, Homegoing, Saga, Volume Three, Y: Th...
# 155      345  [The Obelisk Gate, Paradise Kiss 1, The Hate U...
# 156      472  [Labyrinths, The Perks of Being a Wallflower, ...
# 157      813  [A Little Life, Stone Butch Blues, , Matterhor...
# 158     1177  [The Yellow Wall-paper. A story, The Lion & th...
#
# [159 rows x 2 columns]

# %%
name_dict = {k: v for k, v in enumerate(names)}

# %%
name_dict
# Out:
# {0: 'Brianne',
#  1: 'John',
#  2: 'Bennett',
#  3: 'Brandon',
#  4: 'Yaarit',
#  5: 'Danila',
#  6: 'Daliang',
#  7: 'Steven',
#  8: 'Randolph',
#  9: 'Alex',
#  10: 'Gary',
#  11: 'Julia',
#  12: 'Ilia',
#  13: 'Chang',
#  14: 'Daniel',
#  15: 'Kai',
#  16: 'Jason',
#  17: 'Victoria',
#  18: 'Antoine',
#  19: 'Wenke',
#  20: 'Avi',
#  21: 'Jesse',
#  22: 'Anna',
#  23: 'Nina',
#  24: 'Paul',
#  25: 'Avery',
#  26: 'Hugo',
#  27: 'Charlie',
#  28: 'Dewey',
#  29: 'Jamel',
#  30: 'Magdalena',
#  31: 'Molly',
#  32: 'Sherry',
#  33: 'Curtis',
#  34: 'Thad',
#  35: 'Junior',
#  36: 'Seymour',
#  37: 'Betty',
#  38: 'Otto',
#  39: 'Elsie',
#  40: 'May',
#  41: 'Marcelino',
#  42: 'Roger',
#  43: 'Graciela',
#  44: 'Ashley',
#  45: 'Antony',
#  46: 'Tameka',
#  47: 'Andreas',
#  48: 'Fermin',
#  49: 'Garland',
#  50: 'Sol',
#  51: 'Joshua',
#  52: 'Gavin',
#  53: 'Whitney',
#  54: 'Shelby',
#  55: 'Coy',
#  56: 'Wm',
#  57: 'Myra',
#  58: 'Dalton',
#  59: 'Williams',
#  60: 'Danial',
# ...

# %%
pd.Series(name_dict,index=[k for k in name_dict.keys()])
# Out:
# 0      Brianne
# 1         John
# 2      Bennett
# 3      Brandon
# 4       Yaarit
#         ...
# 133      Ethan
# 134     Dennis
# 135     Taissa
# 136    Ricardo
# 137     Alyssa
# Length: 138, dtype: object

# %%
recs_df['username'] = pd.Series(name_dict,index=[k for k in name_dict.keys()]).values
# Out:
# C:\Users\shinj\Anaconda3\envs\insight\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
recs_df = recs_df[:138]

# %%
recs_df.drop('index',axis=1,inplace=True)

# %%
recs_df.head()
# Out:
#    user_id                                               recs
# 0      534  [The Hate U Give, Crooked Kingdom, Just Mercy:...
# 1      324  [Just Mercy: A Story of Justice and Redemption...
# 3      255  [We Should All Be Feminists, The Fifth Season,...
# 4     1166  [Matterhorn: A Novel of the Vietnam War, The H...
# 5      340  [Just Mercy: A Story of Justice and Redemption...

# %%
recs_df.to_csv('goodreads2/username_recs_sample.csv',index=None)

# %%
df2 = pd.read_csv('goodreads2/username_recs_sample.csv')

# %%
user_df.loc[user_df.title==st,'title'] = 'The Hate U Give'

# %% [markdown]
# rec = '<br>'.join(["Alanna: The First Adventure",
#                                       "The Hunger Games","Pure",
#                                     "Half of a Yellow Sun","Under the Udala Tree"])
#       #### Model goes here
#       recs = pd.read_csv(os.path.join(path,'goodreads2/username_recs_sample.csv'))
#       rec = recs.loc[recs['username']==user_id]['recs'].iloc[0]
#
#          ### model output goes here
#       rec = rec.replace("', '",'<br>')
#       rec = rec.replace("['",'')
#       rec = rec.replace("']",'')
#       rec = rec.replace('"','')
#       rec = rec.replace(']','')

# %%
get_n_rec_user(user_df,1200,model,div_m,test)
# Out:
# ['The Yellow Wall-paper. A story',
#  'The Hate U Give',
#  'Malgudi Days',
#  'Parable of the Talents',
#  "I'll Give You the Sun"]
